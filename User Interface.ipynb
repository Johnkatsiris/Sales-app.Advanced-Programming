# %%
# Import the Tkinter module
import tkinter as tk

# Create the main window
window = tk.Tk()

# Create a label and text entry field
label = tk.Label(window, text="Enter your name:")
entry = tk.Entry(window)

# Pack the label and entry into the window
label.pack()
entry.pack()

# Create a checkbox
checkbox = tk.Checkbutton(window, text="I agree to the terms and conditions")
checkbox.pack()

# Create a radio button
radio_var = tk.IntVar()
radio1 = tk.Radiobutton(window, text="Option 1", variable=radio_var, value=1)
radio2 = tk.Radiobutton(window, text="Option 2", variable=radio_var, value=2)
radio1.pack()
radio2.pack()

# Run the main loop
window.mainloop()

# %%
import tkinter as tk

def submit_text():
    entered_text = text_entry.get()
    print("Entered text:", entered_text)

root = tk.Tk()

text_label = tk.Label(root, text="Enter some text:")
text_label.pack()

text_entry = tk.Entry(root)
text_entry.pack()

submit_button = tk.Button(root, text="Submit", command=submit_text)
submit_button.pack()

root.mainloop()

# %%
pip install Pillow
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import tkinter as tk
from PIL import Image, ImageTk

class StartPage(tk.Frame):
    def __init__(self, parent, controller):
        tk.Frame.__init__(self, parent)
        label = tk.Label(self, text="Welcome to our Graphing Application!", font=("Helvetica", 24))
        label.pack(pady=10, padx=10)

        button1 = tk.Button(self, text="Graph 1 (Image)", command=lambda: controller.show_frame(PageOne))
        button1.pack()

        button2 = tk.Button(self, text="Graph 2 (Image)", command=lambda: controller.show_frame(PageTwo))
        button2.pack()

        button3 = tk.Button(self, text="Graph 3 (Image)", command=lambda: controller.show_frame(PageThree))
        button3.pack()

class PageOne(tk.Frame):
    def __init__(self, parent, controller):
        tk.Frame.__init__(self, parent)
        label = tk.Label(self, text="Graph Image Page", font=("Helvetica", 24))
        label.pack(pady=10, padx=10)

        # Load and display the image
        image = Image.open("Screenshot 2024-05-22 at 5.52.07 PM.png")  # Replace with your image path
        photo = ImageTk.PhotoImage(image)
        img_label = tk.Label(self, image=photo)
        img_label.image = photo  # Keep a reference to avoid garbage collection
        img_label.pack(pady=5, padx=5)

        button = tk.Button(self, text="Back to Home", command=lambda: controller.show_frame(StartPage))
        button.pack()

class PageTwo(tk.Frame):
    def __init__(self, parent, controller):
        tk.Frame.__init__(self, parent)
        label = tk.Label(self, text="Bar Graph Image Page", font=("Helvetica", 24))
        label.pack(pady=10, padx=10)

        # Load and display the image
        image = Image.open("Screenshot 2024-05-22 at 5.58.22 PM.png")  # Replace with your image path
        photo = ImageTk.PhotoImage(image)
        img_label = tk.Label(self, image=photo)
        img_label.image = photo  # Keep a reference to avoid garbage collection
        img_label.pack(pady=10, padx=10)

        button = tk.Button(self, text="Back to Home", command=lambda: controller.show_frame(StartPage))
        button.pack()

class PageThree(tk.Frame):
    def __init__(self, parent, controller):
        tk.Frame.__init__(self, parent)
        label = tk.Label(self, text="Image Page", font=("Helvetica", 24))
        label.pack(pady=10, padx=10)

        # Load and display the image
        image = Image.open("Screenshot 2024-05-22 at 6.50.35 PM.png")  # Replace with your image path
        photo = ImageTk.PhotoImage(image)
        img_label = tk.Label(self, image=photo)
        img_label.image = photo  # Keep a reference to avoid garbage collection
        img_label.pack(pady=10, padx=10)

        button = tk.Button(self, text="Back to Home", command=lambda: controller.show_frame(StartPage))
        button.pack()

class SampleApp(tk.Tk):
    def __init__(self):
        tk.Tk.__init__(self)
        self.title("Graphing Application")
        self.geometry("800x600")
        container = tk.Frame(self)
        container.pack(side="top", fill="both", expand=True)
        container.pack_propagate(False)
        container.grid_rowconfigure(0, weight=1)
        container.grid_columnconfigure(0, weight=1)

        self.frames = {}
        for F in (StartPage, PageOne, PageTwo, PageThree):
            page_name = F.Sales
            frame = F(parent=container, controller=self)
            self.frames[page_name] = frame
            frame.grid(row=0, column=0, sticky="nsew")

        self.show_frame("StartPage")

    def show_frame(self, page_name):
        frame = self.frames[page_name]
        frame.tkraise()

if __name__ == "__main__":
    app = SampleApp()
    app.mainloop()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 92
#      89         frame.tkraise()
#      91 if __name__ == "__main__":
# ---> 92     app = SampleApp()
#      93     app.mainloop()
#
# Cell In[11], line 80, in SampleApp.__init__(self)
#      78 self.frames = {}
#      79 for F in (StartPage, PageOne, PageTwo, PageThree):
# ---> 80     page_name = F.Sales
#      81     frame = F(parent=container, controller=self)
#      82     self.frames[page_name] = frame
#
# AttributeError: type object 'StartPage' has no attribute 'Sales'

# %%
import tkinter as tk
from PIL import Image, ImageTk

class StartPage(tk.Frame):
    def __init__(self, parent, controller):
        tk.Frame.__init__(self, parent)
        label = tk.Label(self, text="Welcome to our Graphing Application!", font=("Helvetica", 24))
        label.pack(pady=10, padx=10)

        button1 = tk.Button(self, text="Graph 1 (Image)", command=lambda: controller.show_frame("PageOne"))
        button1.pack()

        button2 = tk.Button(self, text="Graph 2 (Image)", command=lambda: controller.show_frame("PageTwo"))
        button2.pack()

        button3 = tk.Button(self, text="Graph 3 (Image)", command=lambda: controller.show_frame("PageThree"))
        button3.pack()

class PageOne(tk.Frame):
    def __init__(self, parent, controller):
        tk.Frame.__init__(self, parent)
        label = tk.Label(self, text="Graph Image Page", font=("Helvetica", 24))
        label.pack(pady=10, padx=10)

        # Load and display the image
        image = Image.open("Screenshot 2024-05-22 at 5.58.22 PM.png")  # Replace with your image path
        photo = ImageTk.PhotoImage(image)
        img_label = tk.Label(self, image=photo)
        img_label.image = photo  # Keep a reference to avoid garbage collection
        img_label.pack(pady=5, padx=5)

        button = tk.Button(self, text="Back to Home", command=lambda: controller.show_frame("StartPage"))
        button.pack()

class PageTwo(tk.Frame):
    def __init__(self, parent, controller):
        tk.Frame.__init__(self, parent)
        label = tk.Label(self, text="Bar Graph Image Page", font=("Helvetica", 24))
        label.pack(pady=10, padx=10)

        # Load and display the image
        image = Image.open("Screenshot 2024-05-22 at 5.52.07 PM.png")  # Replace with your image path
        photo = ImageTk.PhotoImage(image)
        img_label = tk.Label(self, image=photo)
        img_label.image = photo  # Keep a reference to avoid garbage collection
        img_label.pack(pady=10, padx=10)

        button = tk.Button(self, text="Back to Home", command=lambda: controller.show_frame("StartPage"))
        button.pack()

class PageThree(tk.Frame):
    def __init__(self, parent, controller):
        tk.Frame.__init__(self, parent)
        label = tk.Label(self, text="Image Page", font=("Helvetica", 24))
        label.pack(pady=10, padx=10)

        # Load and display the image
        image = Image.open("Screenshot 2024-05-22 at 6.50.35 PM.png")  # Replace with your image path
        photo = ImageTk.PhotoImage(image)
        img_label = tk.Label(self, image=photo)
        img_label.image = photo  # Keep a reference to avoid garbage collection
        img_label.pack(pady=10, padx=10)

        button = tk.Button(self, text="Back to Home", command=lambda: controller.show_frame("StartPage"))
        button.pack()

class SampleApp(tk.Tk):
    def __init__(self):
        tk.Tk.__init__(self)
        self.title("Graphing Application")
        self.geometry("800x600")
        container = tk.Frame(self)
        container.pack(side="top", fill="both", expand=True)
        container.pack_propagate(False)
        container.grid_rowconfigure(0, weight=1)
        container.grid_columnconfigure(0, weight=1)

        self.frames = {}
        for F in (StartPage, PageOne, PageTwo, PageThree):
            page_name = F.__name__
            frame = F(parent=container, controller=self)
            self.frames[page_name] = frame
            frame.grid(row=0, column=0, sticky="nsew")

        self.show_frame("StartPage")

    def show_frame(self, page_name):
        frame = self.frames[page_name]
        frame.tkraise()

if __name__ == "__main__":
    app = SampleApp()
    app.mainloop()
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# Cell In[14], line 92
#      89         frame.tkraise()
#      91 if __name__ == "__main__":
# ---> 92     app = SampleApp()
#      93     app.mainloop()
#
# Cell In[14], line 81, in SampleApp.__init__(self)
#      79 for F in (StartPage, PageOne, PageTwo, PageThree):
#      80     page_name = F.__name__
# ---> 81     frame = F(parent=container, controller=self)
#      82     self.frames[page_name] = frame
#      83     frame.grid(row=0, column=0, sticky="nsew")
#
# Cell In[14], line 28, in PageOne.__init__(self, parent, controller)
#      26 image = Image.open("Screenshot 2024-05-22 at 5.58.22 PM.png")  # Replace with your image path
#      27 photo = ImageTk.PhotoImage(image)
# ---> 28 img_label = tk.Label(self, image=photo)
#      29 img_label.image = photo  # Keep a reference to avoid garbage collection
# ...

# %%
import tkinter as tk
from PIL import Image, ImageTk
import os

class StartPage(tk.Frame):
    def __init__(self, parent, controller):
        tk.Frame.__init__(self, parent)
        label = tk.Label(self, text="Welcome to our Graphing Application!", font=("Helvetica", 24))
        label.pack(pady=10, padx=10)

        button1 = tk.Button(self, text="Graph 1 (Image)", command=lambda: controller.show_frame("PageOne"))
        button1.pack()

        button2 = tk.Button(self, text="Graph 2 (Image)", command=lambda: controller.show_frame("PageTwo"))
        button2.pack()

        button3 = tk.Button(self, text="Graph 3 (Image)", command=lambda: controller.show_frame("PageThree"))
        button3.pack()
        
class PageOne(tk.Frame):
    def __init__(self, parent, controller):
        tk.Frame.__init__(self, parent)
        label = tk.Label(self, text="Graph Image Page", font=("Helvetica", 24))
        label.pack(pady=10, padx=10)

        # Load and display the image
        image_path = "Screenshot 2024-05-22 at 5.58.22 PM.png"  # Replace with your image path
        if os.path.exists(image_path):
            self.image = Image.open(image_path)
            self.photo = ImageTk.PhotoImage(self.image)
            img_label = tk.Label(self, image=self.photo)
            img_label.image = self.photo  # Keep a reference to avoid garbage collection
            img_label.pack(pady=5, padx=5)
        else:
            print(f"Image not found: {image_path}")

        button = tk.Button(self, text="Back to Home", command=lambda: controller.show_frame("StartPage"))
        button.pack()

class PageTwo(tk.Frame):
    def __init__(self, parent, controller):
        tk.Frame.__init__(self, parent)
        label = tk.Label(self, text="Bar Graph Image Page", font=("Helvetica", 24))
        label.pack(pady=10, padx=10)

        # Load and display the image
        image_path = "Screenshot 2024-05-22 at 5.52.07 PM.png"  # Replace with your image path
        if os.path.exists(image_path):
            self.image = Image.open(image_path)
            self.photo = ImageTk.PhotoImage(self.image)
            img_label = tk.Label(self, image=self.photo)
            img_label.image = self.photo  # Keep a reference to avoid garbage collection
            img_label.pack(pady=10, padx=10)
        else:
            print(f"Image not found: {image_path}")

        button = tk.Button(self, text="Back to Home", command=lambda: controller.show_frame("StartPage"))
        button.pack()

class PageThree(tk.Frame):
    def __init__(self, parent, controller):
        tk.Frame.__init__(self, parent)
        label = tk.Label(self, text="Image Page", font=("Helvetica", 24))
        label.pack(pady=10, padx=10)

        # Load and display the image
        image_path = "Screenshot 2024-05-22 at 6.50.35 PM.png"  # Replace with your image path
        if os.path.exists(image_path):
            self.image = Image.open(image_path)
            self.photo = ImageTk.PhotoImage(self.image)
            img_label = tk.Label(self, image=self.photo)
            img_label.image = self.photo  # Keep a reference to avoid garbage collection
            img_label.pack(pady=10, padx=10)
        else:
            print(f"Image not found: {image_path}")

        button = tk.Button(self, text="Back to Home", command=lambda: controller.show_frame("StartPage"))
        button.pack()

class SampleApp(tk.Tk):
    def __init__(self):
        tk.Tk.__init__(self)
        self.title("Graphing Application")
        self.geometry("800x600")
        container = tk.Frame(self)
        container.pack(side="top", fill="both", expand=True)
        container.pack_propagate(False)
        container.grid_rowconfigure(0, weight=1)
        container.grid_columnconfigure(0, weight=1)

        self.frames = {}
        for F in (StartPage, PageOne, PageTwo, PageThree):
            page_name = F.__name__
            frame = F(parent=container, controller=self)
            self.frames[page_name] = frame
            frame.grid(row=0, column=0, sticky="nsew")

        self.show_frame("StartPage")

    def show_frame(self, page_name):
        frame = self.frames[page_name]
        frame.tkraise()

if __name__ == "__main__":
    app = SampleApp()
    app.mainloop()
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# Cell In[12], line 105
#     102         frame.tkraise()
#     104 if __name__ == "__main__":
# --> 105     app = SampleApp()
#     106     app.mainloop()
#
# Cell In[12], line 94, in SampleApp.__init__(self)
#      92 for F in (StartPage, PageOne, PageTwo, PageThree):
#      93     page_name = F.__name__
# ---> 94     frame = F(parent=container, controller=self)
#      95     self.frames[page_name] = frame
#      96     frame.grid(row=0, column=0, sticky="nsew")
#
# Cell In[12], line 31, in PageOne.__init__(self, parent, controller)
#      29 self.image = Image.open(image_path)
#      30 self.photo = ImageTk.PhotoImage(self.image)
# ---> 31 img_label = tk.Label(self, image=self.photo)
#      32 img_label.image = self.photo  # Keep a reference to avoid garbage collection
#      33 img_label.pack(pady=5, padx=5)
#
# ...

# %%
import tkinter as tk
from tkinter import messagebox
from PIL import Image, ImageTk

class PageManager(tk.Tk):
    def __init__(self):
        super().__init__()
        self.title("User Interface with Tkinter")
        self.geometry("800x600")
        self.pages = {}
        self.create_pages()

    def create_pages(self):
        # Create instances of each page
        self.pages["WelcomePage"] = WelcomePage(self)
        self.pages["ImagePage1"] = ImagePage(self, "Image Page 1", "/mnt/data/Graph1 profit trends over Time by Segment .png")
        self.pages["ImagePage2"] = ImagePage(self, "Image Page 2", "/mnt/data/Map.png")
        self.pages["ImagePage3"] = ImagePage(self, "Image Page 3", "/mnt/data/Total profit by year.png")

        # Display the welcome page initially
        self.show_page("WelcomePage")

    def show_page(self, page_name):
        page = self.pages[page_name]
        page.tkraise()

class WelcomePage(tk.Frame):
    def __init__(self, parent):
        super().__init__(parent)
        self.parent = parent
        self.grid(row=0, column=0, sticky="nsew")
        self.create_widgets()

    def create_widgets(self):
        tk.Label(self, text="Enter your name:").pack(pady=10)
        self.name_entry = tk.Entry(self)
        self.name_entry.pack(pady=5)
        
        self.conditions_var = tk.BooleanVar()
        tk.Checkbutton(self, text="Accept conditions", variable=self.conditions_var).pack(pady=5)
        
        tk.Button(self, text="Go to Image Page 1", command=self.go_to_image_page_1).pack(pady=5)
        tk.Button(self, text="Go to Image Page 2", command=self.go_to_image_page_2).pack(pady=5)
        tk.Button(self, text="Go to Image Page 3", command=self.go_to_image_page_3).pack(pady=5)

    def go_to_image_page(self, page_name):
        name = self.name_entry.get()
        if not name:
            messagebox.showwarning("Input Error", "Please enter your name.")
        elif not self.conditions_var.get():
            messagebox.showwarning("Input Error", "Please accept the conditions.")
        else:
            self.parent.show_page(page_name)

    def go_to_image_page_1(self):
        self.go_to_image_page("ImagePage1")

    def go_to_image_page_2(self):
        self.go_to_image_page("ImagePage2")

    def go_to_image_page_3(self):
        self.go_to_image_page("ImagePage3")

class ImagePage(tk.Frame):
    def __init__(self, parent, title, image_path):
        super().__init__(parent)
        self.parent = parent
        self.title = title
        self.image_path = image_path
        self.grid(row=0, column=0, sticky="nsew")
        self.create_widgets()

    def create_widgets(self):
        tk.Label(self, text=self.title).pack(pady=10)
        
        # Load and display the image
        image = Image.open(self.image_path)
        image = image.resize((600, 400), Image.ANTIALIAS)
        self.photo = ImageTk.PhotoImage(image)
        tk.Label(self, image=self.photo).pack(pady=10)
        
        tk.Button(self, text="Back to Welcome Page", command=self.go_back).pack(pady=5)

    def go_back(self):
        self.parent.show_page("WelcomePage")

if __name__ == "__main__":
    app = PageManager()
    app.mainloop()

# %%
import tkinter as tk
from tkinter import messagebox
from PIL import Image, ImageTk

class PageManager(tk.Tk):
    def __init__(self):
        super().__init__()
        self.title("User Interface with Tkinter")
        self.geometry("400x300")
        self.pages = {}
        self.create_pages()

    def create_pages(self):
        # Create instances of each page
        self.pages["WelcomePage"] = WelcomePage(self)
        self.pages["ImagePage1"] = ImagePage(self, "Image Page 1", "Profit .png")
        self.pages["ImagePage2"] = ImagePage(self, "Image Page 2", "Map.png")
        self.pages["ImagePage3"] = ImagePage(self, "Image Page 3", "Total profit by year.png")

        # Display the welcome page initially
        self.show_page("WelcomePage")

    def show_page(self, page_name):
        page = self.pages[page_name]
        page.tkraise()

class WelcomePage(tk.Frame):
    def __init__(self, parent):
        super().__init__(parent)
        self.parent = parent
        self.grid(row=0, column=0, sticky="nsew")
        self.create_widgets()

    def create_widgets(self):
        tk.Label(self, text="Enter your name:").pack(pady=10)
        self.name_entry = tk.Entry(self)
        self.name_entry.pack(pady=5)
        
        self.conditions_var = tk.BooleanVar()
        tk.Checkbutton(self, text="Accept conditions", variable=self.conditions_var).pack(pady=5)
        
        tk.Button(self, text="Go to Image Page 1", command=self.go_to_image_page_1).pack(pady=5)
        tk.Button(self, text="Go to Image Page 2", command=self.go_to_image_page_2).pack(pady=5)
        tk.Button(self, text="Go to Image Page 3", command=self.go_to_image_page_3).pack(pady=5)

    def go_to_image_page(self, page_name):
        name = self.name_entry.get()
        if not name:
            messagebox.showwarning("Input Error", "Please enter your name.")
        elif not self.conditions_var.get():
            messagebox.showwarning("Input Error", "Please accept the conditions.")
        else:
            self.parent.show_page(page_name)

    def go_to_image_page_1(self):
        self.go_to_image_page("ImagePage1")

    def go_to_image_page_2(self):
        self.go_to_image_page("ImagePage2")

    def go_to_image_page_3(self):
        self.go_to_image_page("ImagePage3")

class ImagePage(tk.Frame):
    def __init__(self, parent, title, image_path):
        super().__init__(parent)
        self.parent = parent
        self.title = title
        self.image_path = image_path
        self.grid(row=0, column=0, sticky="nsew")
        self.create_widgets()

    def create_widgets(self):
        tk.Label(self, text=self.title).pack(pady=10)
        
        # Load and display the image
        image = Image.open(self.image_path)
        image = image.resize((300, 200), Image.ANTIALIAS)
        self.photo = ImageTk.PhotoImage(image)
        tk.Label(self, image=self.photo).pack(pady=10)
        
        tk.Button(self, text="Back to Welcome Page", command=self.go_back).pack(pady=5)

    def go_back(self):
        self.parent.show_page("WelcomePage")

if __name__ == "__main__":
    app = PageManager()
    app.mainloop()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[23], line 88
#      85         self.parent.show_page("WelcomePage")
#      87 if __name__ == "__main__":
# ---> 88     app = PageManager()
#      89     app.mainloop()
#
# Cell In[23], line 11, in PageManager.__init__(self)
#       9 self.geometry("400x300")
#      10 self.pages = {}
# ---> 11 self.create_pages()
#
# Cell In[23], line 16, in PageManager.create_pages(self)
#      13 def create_pages(self):
#      14     # Create instances of each page
#      15     self.pages["WelcomePage"] = WelcomePage(self)
# ---> 16     self.pages["ImagePage1"] = ImagePage(self, "Image Page 1", "Profit .png")
#      17     self.pages["ImagePage2"] = ImagePage(self, "Image Page 2", "Map.png")
#      18     self.pages["ImagePage3"] = ImagePage(self, "Image Page 3", "Total profit by year.png")
#
# ...

# %%
import tkinter as tk
from tkinter import messagebox
from PIL import Image, ImageTk

class PageManager(tk.Tk):
    def __init__(self):
        super().__init__()
        self.title("User Interface with Tkinter")
        self.geometry("800x600")
        self.pages = {}
        self.create_pages()

    def create_pages(self):
        # Create instances of each page
        self.pages["WelcomePage"] = WelcomePage(self)
        self.pages["ImagePage1"] = ImagePage(self, "Image Page 1", "Profit .png")
        self.pages["ImagePage2"] = ImagePage(self, "Image Page 2", "Map.png")
        self.pages["ImagePage3"] = ImagePage(self, "Image Page 3", "Total profit by year.png")

        # Display the welcome page initially
        self.show_page("WelcomePage")

    def show_page(self, page_name):
        page = self.pages[page_name]
        page.tkraise()

class WelcomePage(tk.Frame):
    def __init__(self, parent):
        super().__init__(parent)
        self.parent = parent
        self.grid(row=0, column=0, sticky="nsew")
        self.create_widgets()

    def create_widgets(self):
        tk.Label(self, text="Enter your name:").pack(pady=10)
        self.name_entry = tk.Entry(self)
        self.name_entry.pack(pady=5)
        
        self.conditions_var = tk.BooleanVar()
        tk.Checkbutton(self, text="Accept conditions", variable=self.conditions_var).pack(pady=5)
        
        tk.Button(self, text="Go to Image Page 1", command=lambda: self.go_to_image_page("ImagePage1")).pack(pady=5)
        tk.Button(self, text="Go to Image Page 2", command=lambda: self.go_to_image_page("ImagePage2")).pack(pady=5)
        tk.Button(self, text="Go to Image Page 3", command=lambda: self.go_to_image_page("ImagePage3")).pack(pady=5)

    def go_to_image_page(self, page_name):
        name = self.name_entry.get()
        if not name:
            messagebox.showwarning("Input Error", "Please enter your name.")
        elif not self.conditions_var.get():
            messagebox.showwarning("Input Error", "Please accept the conditions.")
        else:
            self.parent.show_page(page_name)

class ImagePage(tk.Frame):
    def __init__(self, parent, title, image_path):
        super().__init__(parent)
        self.parent = parent
        self.title = title
        self.image_path = image_path
        self.grid(row=0, column=0, sticky="nsew")
        self.create_widgets()

    def create_widgets(self):
        tk.Label(self, text=self.title).pack(pady=10)
        
        # Load and display the image
        try:
            image = Image.open(self.image_path)
            image = image.resize((600, 400), Image.LANCZOS)
            self.photo = ImageTk.PhotoImage(image)
            tk.Label(self, image=self.photo).pack(pady=10)
        except Exception as e:
            messagebox.showerror("Image Error", f"Failed to load image: {e}")
        
        tk.Button(self, text="Back to Welcome Page", command=self.go_back).pack(pady=5)

    def go_back(self):
        self.parent.show_page("WelcomePage")

if __name__ == "__main__":
    app = PageManager()
    app.mainloop()
